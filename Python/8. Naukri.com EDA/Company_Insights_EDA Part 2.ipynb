# %%
# !git clone 'https://github.com/HarshvardhanSingh-13/Datasets'
# Out:
# fatal: destination path 'Datasets' already exists and is not an empty directory.

# %%
import pandas as pd

# %% [markdown]
# # 1) Overall Exploration

# %% [markdown]
# #### 1.1) Loading the dataset

# %%
df = pd.read_csv('/content/Datasets/Job Postings/jobs.csv.zip')
df.head()
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                       Product Owner Senior Manager  Accenture
# 2  6.012391e+10  Employee Relations and Policies Associate Manager  Accenture
# 3  6.012391e+10         Employee Relations and Policies Specialist  Accenture
# 4  6.012301e+10                                  SAP BO Consultant   Mindtree
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
# 2    3-7 Yrs  Not disclosed
# 3    3-7 Yrs  Not disclosed
# 4    5-7 Yrs  Not disclosed
#
#                                             location  rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# ...

# %%
'''
KPI's

1) Calculate the average rating for each company.
2) Identify companies with the highest and lowest average ratings.
3) Compare the distribution of ratings across different companies.
4) Calculate the total number of reviews for each company.
5) List the top 10 companies based on average rating and number of reviews.
6) Identify the top responsibilities for each role

7) Lowest and Highest Rating Companies
8) Number of Active Jobs in any company | Top Companies
8) Companies which provide Max/Min Average Salary
9) Salary Vs Expectation of any company
10) Companies hiring for most numbers of location

'''

# %% [markdown]
# #### 1.2) Information about the datset

# %%
df['salary'].value_counts()
# Out:
# salary
# Not disclosed                                          45544
# 6,50,000 - 9,00,000 PA.                                 3330
# 6,00,000 - 8,00,000 PA.                                 1114
# 5,00,000 - 10,00,000 PA.                                1087
# 2,50,000 - 3,50,000 PA.                                  599
#                                                        ...
# 4,00,000 - 9,00,000 PA. (Including Variable: 20.0%)        1
# 4,00,00,000 - 4,50,00,000 PA.                              1
# 2,00,000 - 6,00,000 PA. (Including Variable: 30.0%)        1
# 60,00,000 - 1,00,00,000 PA.                                1
# 75,00,000 - 1,00,00,000 PA.                                1
# Name: count, Length: 813, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79147 entries, 0 to 79146
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   job_id           78667 non-null  float64
#  1   job_role         78667 non-null  object
#  2   company          78666 non-null  object
#  3   experience       77398 non-null  object
#  4   salary           78667 non-null  object
#  5   location         77441 non-null  object
#  6   rating           42948 non-null  float64
#  7   reviews          42948 non-null  object
#  8   resposibilities  78647 non-null  object
#  9   posted_on        78667 non-null  object
#  10  job_link         78667 non-null  object
#  11  company_link     78667 non-null  object
# dtypes: float64(2), object(10)
# memory usage: 7.2+ MB

# %%
df.describe()
# Out:
#              job_id        rating
# count  7.866700e+04  42948.000000
# mean   1.255071e+11      3.940144
# std    1.097464e+11      0.519211
# min    1.012200e+10      1.000000
# 25%    4.012350e+10      3.700000
# 50%    6.012350e+10      4.000000
# 75%    2.610226e+11      4.200000
# max    3.112229e+11      5.000000

# %% [markdown]
# #### 1.3) Checking for null values

# %%
df.isnull().sum()
# Out:
# job_id               480
# job_role             480
# company              481
# experience          1749
# salary               480
# location            1706
# rating             36199
# reviews            36199
# resposibilities      500
# posted_on            480
# job_link             480
# company_link         480
# dtype: int64

# %% [markdown]
# #### 1.4) Removing Column 'posted_on'

# %%
df['posted_on'].unique()
# Out:
# array(['1 Day Ago', '3 Days Ago', '2 Days Ago', 'Walk-in3 Days Ago',
#        '7 Days Ago', '9 Days Ago', '5 Days Ago', '4 Days Ago',
#        '6 Days Ago', '8 Days Ago', 'Today', '10 Days Ago',
#        'Walk-in1 Day Ago', 'Walk-in2 Days Ago', 'Walk-in4 Days Ago',
#        'Walk-in5 Days Ago', 'Just Now', 'Walk-inJust Now',
#        'Walk-in9 Days Ago', 'Walk-in8 Days Ago', 'Walk-in10 Days Ago',
#        'Walk-in6 Days Ago', 'Few Hours Ago', 'Walk-in7 Days Ago',
#        'Walk-inFew Hours Ago', 'Walk-inToday', nan], dtype=object)

# %%
del df['posted_on']
df
# Out:
#              job_id                                           job_role  \
# 0      7.012301e+10      Branch Banking - Calling For Women Candidates
# 1      6.012391e+10                       Product Owner Senior Manager
# 2      6.012391e+10  Employee Relations and Policies Associate Manager
# 3      6.012391e+10         Employee Relations and Policies Specialist
# 4      6.012301e+10                                  SAP BO Consultant
# ...             ...                                                ...
# 79142  6.012301e+10                           .Net Fullstack Developer
# 79143  1.122201e+10        Senior (BI) Business Intelligence Architect
# 79144  1.512220e+11                                  PowerBI Developer
# 79145  2.712220e+11                         Customer Service Associate
# 79146  2.112220e+11                   Senior Java BED ( PAN India)- KG
#
#                      company experience                     salary  \
# ...

# %% [markdown]
# #### 1.5) Removing Null Values

# %%
df.isnull().sum()
# Out:
# job_id               480
# job_role             480
# company              481
# experience          1749
# salary               480
# location            1706
# rating             36199
# reviews            36199
# resposibilities      500
# job_link             480
# company_link         480
# dtype: int64

# %%
df.dropna(subset=['job_id']).isnull().sum()
# Out:
# job_id                 0
# job_role               0
# company                1
# experience          1269
# salary                 0
# location            1226
# rating             35719
# reviews            35719
# resposibilities       20
# job_link               0
# company_link           0
# dtype: int64

# %%
df.dropna(subset=['job_id','company']).isnull().sum()
# Out:
# job_id                 0
# job_role               0
# company                0
# experience          1269
# salary                 0
# location            1226
# rating             35719
# reviews            35719
# resposibilities       20
# job_link               0
# company_link           0
# dtype: int64

# %%
df.dropna(subset=['job_id','company','resposibilities'], inplace=True)

# %%
df.dropna(subset=['job_id','company','resposibilities','location','experience']).isnull().sum()
# Out:
# job_id                 0
# job_role               0
# company                0
# experience             0
# salary                 0
# location               0
# rating             35401
# reviews            35401
# resposibilities        0
# job_link               0
# company_link           0
# dtype: int64

# %%
len(df)
# Out:
# 79147

# %%
len(df.dropna(subset=['job_id','company','resposibilities']))
# Out:
# 78646

# %%
df['location'].mode()[0]
# Out:
# 'Bangalore/Bengaluru'

# %%
df['location'].value_counts()
# Out:
# location
# Bangalore/Bengaluru                                                                          10035
# Hyderabad/Secunderabad                                                                        3736
# Pune                                                                                          3216
# Chennai                                                                                       2953
# Mumbai                                                                                        2818
#                                                                                              ...
# Panvel, Andheri, Nerul                                                                           1
# Surendranagar, Mehsana, Gandhinagar, Sanand, Ahmedabad, Rajkot                                   1
# Kalol, Mahesana, Surendranagar, Mundra, Morvi, Gandhinagar, Patan, Deesa, Ahmedabad              1
# ...

# %%
df['experience'].value_counts()
# Out:
# experience
# 5-10 Yrs     8041
# 3-8 Yrs      4451
# 1-6 Yrs      3302
# 4-9 Yrs      3186
# 2-7 Yrs      3079
#              ...
# 20-26 Yrs       1
# 22-28 Yrs       1
# 19-24 Yrs       1
# 16-21 Yrs       1
# 20-29 Yrs       1
# Name: count, Length: 231, dtype: int64

# %%
df['location'].mode()[0]
# Out:
# 'Bangalore/Bengaluru'

# %%
df['experience'].mode()[0]
# Out:
# '5-10 Yrs'

# %%
df.isnull().sum()
# Out:
# job_id                 0
# job_role               0
# company                0
# experience          1268
# salary                 0
# location            1226
# rating             35718
# reviews            35718
# resposibilities        0
# job_link               0
# company_link           0
# dtype: int64

# %%
df['location'] = df['location'].fillna(df['location'].mode()[0])

# %%
df['experience'] = df['experience'].fillna(df['experience'].mode()[0])

# %%
df['experience'].mode()
# Out:
# 0    5-10 Yrs
# Name: experience, dtype: object

# %%
df.isnull().sum()
# Out:
# job_id                 0
# job_role               0
# company                0
# experience             0
# salary                 0
# location               0
# rating             35718
# reviews            35718
# resposibilities        0
# job_link               0
# company_link           0
# dtype: int64

# %%
df['rating'].unique()
# Out:
# array([4. , 4.1, 3.9, 3.7, 3.8, 4.5, 4.3, 4.2, 4.4, 3.1, 3.3, 3.6, 3.5,
#        3.4, nan, 5. , 4.7, 3. , 4.8, 3.2, 4.6, 2.9, 2.8, 2.6, 2.5, 2.2,
#        2.3, 2.7, 4.9, 1.1, 2.4, 1.8, 2. , 1. , 1.7, 1.9, 2.1, 1.5, 1.6,
#        1.4, 1.2, 1.3])

# %%
df['reviews'].unique()
# Out:
# array(['39110 Reviews', '32129 Reviews', '3759 Reviews', '10263 Reviews',
#        '23786 Reviews', '3843 Reviews', '21440 Reviews', '742 Reviews',
#        '18348 Reviews', '218 Reviews', '3172 Reviews', '6258 Reviews',
#        '1441 Reviews', '33480 Reviews', '50163 Reviews', '19288 Reviews',
#        '1190 Reviews', '28658 Reviews', '1686 Reviews', '981 Reviews',
#        '24041 Reviews', '370 Reviews', '56 Reviews', '4744 Reviews',
#        '601 Reviews', '2060 Reviews', '345 Reviews', '1138 Reviews',
#        '1462 Reviews', '1503 Reviews', '3827 Reviews', '274 Reviews',
#        '802 Reviews', '5169 Reviews', '311 Reviews', '4786 Reviews',
#        '59 Reviews', '2611 Reviews', '321 Reviews', '1232 Reviews',
#        '236 Reviews', '613 Reviews', '986 Reviews', '71 Reviews',
#        '102 Reviews', '4795 Reviews', '3118 Reviews', '18335 Reviews',
#        '1747 Reviews', '2239 Reviews', '136 Reviews', '234 Reviews',
# ...

# %%
df['rating'] = df['rating'].fillna(0.0)

# %%
df['reviews'] = df['reviews'].fillna('0 Reviews')

# %%
df.isnull().sum()
# Out:
# job_id             0
# job_role           0
# company            0
# experience         0
# salary             0
# location           0
# rating             0
# reviews            0
# resposibilities    0
# job_link           0
# company_link       0
# dtype: int64

# %%
df
# Out:
#              job_id                                           job_role  \
# 0      7.012301e+10      Branch Banking - Calling For Women Candidates
# 1      6.012391e+10                       Product Owner Senior Manager
# 2      6.012391e+10  Employee Relations and Policies Associate Manager
# 3      6.012391e+10         Employee Relations and Policies Specialist
# 4      6.012301e+10                                  SAP BO Consultant
# ...             ...                                                ...
# 79142  6.012301e+10                           .Net Fullstack Developer
# 79143  1.122201e+10        Senior (BI) Business Intelligence Architect
# 79144  1.512220e+11                                  PowerBI Developer
# 79145  2.712220e+11                         Customer Service Associate
# 79146  2.112220e+11                   Senior Java BED ( PAN India)- KG
#
#                      company experience                     salary  \
# ...

# %% [markdown]
# #### 1.6) Removing Duplicates

# %%
len(df.drop_duplicates(subset='job_id'))
# Out:
# 73010

# %%
len(df)
# Out:
# 79147

# %%
len(df.drop_duplicates(subset='job_link'))
# Out:
# 73010

# %%
df.drop_duplicates(subset='job_id', inplace = True)

# %%
len(df)
# Out:
# 73010

# %% [markdown]
# # 2) Column Wise Data Cleaning

# %%
df.head(3)
# Out:
#          job_id                                           job_role    company  \
# 0  7.012301e+10      Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                       Product Owner Senior Manager  Accenture
# 2  6.012391e+10  Employee Relations and Policies Associate Manager  Accenture
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
# 2    3-7 Yrs  Not disclosed
#
#                                             location  rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
# 2  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
#
#                                      resposibilities  \
# 0     Customer Service,Sales,Relationship Management
# 1  Product management,Market analysis,Change mana...
# 2  Business process,Change management,Team manage...
#
# ...

# %% [markdown]
# #### 2.1) Job_id Exploration

# %%
df['job_id'].value_counts()
# Out:
# job_id
# 7.102201e+10    1
# 2.912220e+11    1
# 2.012301e+10    1
# 2.012301e+10    1
# 2.012301e+10    1
#                ..
# 6.012301e+10    1
# 6.012301e+10    1
# 6.012391e+10    1
# 6.012391e+10    1
# 6.012391e+10    1
# Name: count, Length: 73009, dtype: int64

# %%
df['job_id'].nunique()
# Out:
# 73009

# %% [markdown]
# #### 2.2) Job Role Exploration

# %%
df['job_role'].head(20)
# Out:
# 0         Branch Banking - Calling For Women Candidates
# 1                          Product Owner Senior Manager
# 2     Employee Relations and Policies Associate Manager
# 3            Employee Relations and Policies Specialist
# 4                                     SAP BO Consultant
# 5     ServiceNow Consultants / Sr. Consultants ( Dev...
# 6     C++ Developer (Looking For immediate joiners o...
# 7     Functional Architect -  Oracle Supply Chain Ma...
# 8                         People Advisor Senior Analyst
# 9                    HR Service Delivery Senior Analyst
# 10                              Data Science Specialist
# 11                                    Solution Designer
# 12    Hiring-Java-Pune/Mumbai/Bangalore/Hyderabad/Ch...
# 13                                     Splunk Developer
# 14                             Automation Test Engineer
# 15    Unified Functional Testing/UFT Automation Testing
# 16                   Senior Product Experience Engineer
# ...

# %% [markdown]
# #### 2.3) Company Exploration

# %%
df['company'].value_counts()
# Out:
# company
# Lavya Associates                                5128
# Accenture                                       2928
# Hucon                                            852
# Varite India Pvt. Ltd.                           815
# IBM                                              656
#                                                 ...
# Centre For Social Responsibility  Leadership       1
# NEW Era Solutions Private Limied                   1
# Nuerepa Biotechnology                              1
# Texon Vietnam                                      1
# Tirupati Group                                     1
# Name: count, Length: 15313, dtype: int64

# %%
df[df['company'] == 'Lavya Associates']['company_link'].unique()
# Out:
# array(['https://www.naukri.com/lavya-associates-hr-services-jobs-careers-932996',
#        'https://www.naukri.com/lavya-associates-jobs-careers-932996'],
#       dtype=object)

# %%
df[df['company_link'] == 'https://www.naukri.com/lavya-associates-hr-services-jobs-careers-932996']['company'].unique()
# Out:
# array(['Lavya Associates HR Services', 'Lavya Associates'], dtype=object)

# %% [markdown]
# #### 2.4) Experience Exploration

# %%
df
# Out:
#              job_id                                           job_role  \
# 0      7.012301e+10      Branch Banking - Calling For Women Candidates
# 1      6.012391e+10                       Product Owner Senior Manager
# 2      6.012391e+10  Employee Relations and Policies Associate Manager
# 3      6.012391e+10         Employee Relations and Policies Specialist
# 4      6.012301e+10                                  SAP BO Consultant
# ...             ...                                                ...
# 73762  2.012300e+10            Partner Success Executive/Edtech/Punjab
# 73763  2.012300e+10            Partner Success Associate/Edtech/Punjab
# 73764  2.312220e+11  Hiring For International Voice Process | Gurga...
# 73765  1.712200e+11                                   Fresher Engineer
# 73766  7.102201e+10            Anatomy Trainer - Part Time / Full time
#
#                      company experience                   salary  \
# ...

# %%
len(df['experience'])
# Out:
# 73010

# %%
c = 0

for i in df['experience']:
  if len(i.split()) == 2:
    c += 1

print(c)
# Out:
# 72988

# %%
count=0

for i in df['experience']:
  if(len(i.split())==2):
    count= count +1
print(count)
# Out:
# 72988

# %%
len(df['experience'])
# Out:
# 72988

# %%
df['start_exp'] = df['experience'].str.replace('Yrs','').str.strip().str.split('-').str[0]

# %%
df['end_exp'] = df['experience'].str.replace('Yrs','').str.strip().str.split('-').str[1]

# %%
df
# Out:
#              job_id                                           job_role  \
# 0      7.012301e+10      Branch Banking - Calling For Women Candidates
# 1      6.012391e+10                       Product Owner Senior Manager
# 2      6.012391e+10  Employee Relations and Policies Associate Manager
# 3      6.012391e+10         Employee Relations and Policies Specialist
# 4      6.012301e+10                                  SAP BO Consultant
# ...             ...                                                ...
# 73762  2.012300e+10            Partner Success Executive/Edtech/Punjab
# 73763  2.012300e+10            Partner Success Associate/Edtech/Punjab
# 73764  2.312220e+11  Hiring For International Voice Process | Gurga...
# 73765  1.712200e+11                                   Fresher Engineer
# 73766  7.102201e+10            Anatomy Trainer - Part Time / Full time
#
#                      company experience                   salary  \
# ...

# %%
df['salary'].unique()
# Out:
# array(['Not disclosed', '7,00,000 - 17,00,000 PA.',
#        '10,00,000 - 20,00,000 PA.',
#        '4,00,000 - 9,00,000 PA. (Including Variable: 20.0%)',
#        '2,50,000 - 3,50,000 PA.', '25,00,000 - 27,50,000 PA.',
#        '13,00,000 - 22,50,000 PA.', '8,50,000 - 18,50,000 PA.',
#        '4,25,000 - 4,50,000 PA.', '5,50,000 - 15,50,000 PA.',
#        '5,50,000 - 14,00,000 PA.', '8,00,000 - 18,00,000 PA.',
#        '50,000 - 3,00,000 PA.', '4,75,000 PA.', '6,00,000 - 8,00,000 PA.',
#        '8,00,000 - 12,00,000 PA.', '5,00,000 - 15,00,000 PA.',
#        '6,00,000 - 16,00,000 PA.', '5,00,000 - 14,00,000 PA.',
#        '10,00,000 - 18,00,000 PA.', '18,00,000 - 20,00,000 PA.',
#        '4,00,000 - 7,00,000 PA.', '2,00,000 - 7,00,000 PA.',
#        '20,00,000 - 30,00,000 PA.', '8,00,000 - 16,00,000 PA.',
#        '3,00,000 - 6,50,000 PA.', '2,00,000 - 6,00,000 PA.', '50,000 PA.',
#        '15,00,000 - 20,00,000 PA.', '9,00,000 - 19,00,000 PA.',
# ...

# %%
df.head(2)
# Out:
#          job_id                                       job_role    company  \
# 0  7.012301e+10  Branch Banking - Calling For Women Candidates  Hdfc Bank
# 1  6.012391e+10                   Product Owner Senior Manager  Accenture
#
#   experience         salary  \
# 0    1-6 Yrs  Not disclosed
# 1  11-15 Yrs  Not disclosed
#
#                                             location  rating        reviews  \
# 0  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...     4.0  39110 Reviews
# 1  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...     4.1  32129 Reviews
#
#                                      resposibilities  \
# 0     Customer Service,Sales,Relationship Management
# 1  Product management,Market analysis,Change mana...
#
#                                             job_link  \
# 0  https://www.naukri.com/job-listings-branch-ban...
# 1  https://www.naukri.com/job-listings-product-ow...
#
#                                         company_link start_exp end_exp
# ...
